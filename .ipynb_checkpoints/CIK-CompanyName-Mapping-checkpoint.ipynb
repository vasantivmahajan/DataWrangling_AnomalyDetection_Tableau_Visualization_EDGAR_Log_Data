# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.request as ur
CIKs = []
companyNames = []
path = '.'
files = ['cik-list.txt']
for f in files:
    
      with open (f, "r") as myfile:
        for line in myfile:
            #print(line)
            values=line.split(':')
            companyNames.append(values[len(values)-3])
            CIKs.append(values[(len(values)-2)].strip('0'))
    
        


df = pd.DataFrame({'CIK': CIKs, 'company': companyNames})
df.to_csv('CIK-mapping.csv')
df.head()
# Out:
#        CIK                             company
# 0  1438823                              !J INC
# 1  1509607       #1 A LIFESAFER HOLDINGS, INC.
# 2  1457512  #1 ARIZONA DISCOUNT PROPERTIES LLC
# 3  1433777                   #1 PAINTBALL CORP
# 4  1427189                               $ LLC

# %%
df
# Out:
#                CIK                                  company
# 0       0001438823                                   !J INC
# 1       0001509607            #1 A LIFESAFER HOLDINGS, INC.
# 2       0001457512       #1 ARIZONA DISCOUNT PROPERTIES LLC
# 3       0001433777                        #1 PAINTBALL CORP
# 4       0001427189                                    $ LLC
# 5       0001447162                      & S MEDIA GROUP LLC
# 6       0001479357                  &TV COMMUNICATIONS INC.
# 7       0000886475                             'MKTG, INC.'
# 8       0001599496        (OURCROWD INVESTMENT IN MST) L.P.
# 9       0001623088                       (Y.Z) QUEENCO LTD.
# 10      0001577787                       .CLUB DOMAINS, LLC
# 11      0001402606             012 SMILE.COMMUNICATIONS LTD
# 12      0001409768                           02 MEDTECH INC
# 13      0001494698                                0210, LLC
# 14      0001307969                         024 PHARMA, INC.
# 15      0001414080                            02DIESEL CORP
# 16      0001322914               03 ENTERTAINMENT GROUP INC
# 17      0001114831               033 ASSET MANAGEMENT LLC /
# 18      0001398981              05 AFWAIN COURITY KATHY LLC
# 19      0001406134        05 CAT THIEF/GOLD IN MY STARS LLC
# 20      0001395687            05 DIXIE UNION/UNDER FIRE LLC
# 21      0001398457           05 EL CORREDOR/ONE BAD CAT LLC
# 22      0001402813              05 FREUD/LAVISH NUMBERS LLC
# 23      0001398456               05 GOLD CASE/JETAZELLE LLC
# 24      0001394816             05 HOLD THAT TIGER TOJUR LLC
# 25      0001395686  05 INDIAN CHARLIE/HELLO KITTY KITTY LLC
# 26      0001399020              05 KAFWAIN JOVIAL WINGS LLC
# 27      0001398982        05 LIDO PALACEMADA MEADOWLAKE LLC
# 28      0001394815             05 MACHO UNO GO DONNA GO LLC
# 29      0001406031         05 MALABAR GOLD/KNOCK ON GIN LLC
# ...            ...                                      ...
# 650995  0001674166                                 ZYPE INC
# 650996  0001678008                             ZYPPAH, INC.
# 650997  0001584115                              ZYPSEE INC.
# 650998  0001689459                          ZYPTONITE, INC.
# 650999  0001138409                       ZYRAY WIRELESS INC
# 651000  0001558263                           ZYRIANOV DENIS
# 651001  0001132581                    ZYRION TECHNOLOGY INC
# 651002  0001558740           ZYROX MINING INTERNATIONAL INC
# 651003  0001505145                               ZYRRA INC.
# 651004  0001412002                                ZYRRA LLC
# 651005  0001443679                           ZYSBLAT ROBERT
# 651006  0001380832                          ZYSKIND BARRY D
# 651007  0001376034                            ZYSKIND BERYL
# 651008  0001676502                              ZYSTON, LLC
# 651009  0000912092                          ZYTEC CORP /MN/
# 651010  0001406796                                ZYTO CORP
# 651011  0001696231                        ZYUDLY LABS, INC.
# 651012  0001317728                              ZYUZIN IGOR
# 651013  0001629078                         ZYUZIN KIRILL I.
# 651014  0001629122                         ZYUZINA IRINA V.
# 651015  0001629075                        ZYUZINA KSENIA I.
# 651016  0001439203          ZYVEK PERFORMANCE MATERIALS INC
# 651017  0001230900                               ZYVEX CORP
# 651018  0001657236                              ZYWIE, INC.
# 651019  0001383819                           ZZ BIOTECH LLC
# 651020  0001501460                            ZZ GLOBAL LLC
# 651021  0001448632                 ZZIF 2008 INVESTMENT LLC
# 651022  0001365357         ZZLL INFORMATION TECHNOLOGY, INC
# 651023  0001691924                                 ZZX, LLC
# 651024  0001184274                    ZZYZX ZZAZX ZZOZX INC
#
# [651025 rows x 2 columns]
